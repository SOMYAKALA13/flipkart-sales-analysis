# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Somya Kala\OneDrive\Documents\FLIPKART\flipkart_sales_enriched.csv")

# %%
df
# Out:
#      Order ID      Product Name        Category  Price (INR)  Quantity Sold  \
# 0    ORD00001  Educational Book           Books     49069.56              2
# 1    ORD00002             Jeans        Clothing     12755.85              4
# 2    ORD00003        Face Cream          Beauty     11092.19              4
# 3    ORD00004        Smartwatch     Electronics     32657.81              1
# 4    ORD00005      Cookware Set  Home & Kitchen     26590.08              3
# ..        ...               ...             ...          ...            ...
# 995  ORD00996        Smartphone     Electronics     28995.81              3
# 996  ORD00997           Perfume          Beauty     32799.51              2
# 997  ORD00998        Face Cream          Beauty     40840.80              1
# 998  ORD00999      Cookware Set  Home & Kitchen     34741.79              4
# 999  ORD01000        Table Lamp  Home & Kitchen     16698.12              4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1000 non-null   object
#  1   Product Name       1000 non-null   object
#  2   Category           1000 non-null   object
#  3   Price (INR)        1000 non-null   float64
#  4   Quantity Sold      1000 non-null   int64
#  5   Total Sales (INR)  1000 non-null   float64
#  6   Order Date         1000 non-null   object
#  7   Payment Method     1000 non-null   object
#  8   Customer Rating    1000 non-null   float64
#  9   Month              1000 non-null   object
#  10  Year               1000 non-null   int64
#  11  Profit (INR)       1000 non-null   float64
#  12  Discount %         1000 non-null   int64
#  13  Customer Segment   1000 non-null   object
#  14  Region             1000 non-null   object
# dtypes: float64(4), int64(3), object(8)
# ...

# %%
df.describe()
# Out:
#         Price (INR)  Quantity Sold  Total Sales (INR)  Customer Rating  \
# count   1000.000000    1000.000000        1000.000000      1000.000000
# mean   24520.258260       3.097000       75213.112740         3.011100
# std    14187.611227       1.410525       59457.598352         1.145408
# min      139.850000       1.000000         419.550000         1.000000
# 25%    12378.905000       2.000000       28581.765000         2.000000
# 50%    24650.015000       3.000000       57358.300000         3.100000
# 75%    35981.925000       4.000000      110618.595000         4.000000
# max    49911.750000       5.000000      243903.900000         5.000000
#
#               Year  Profit (INR)   Discount %
# count  1000.000000   1000.000000  1000.000000
# mean   2024.103000  15042.622548    17.699000
# std       0.304111  11891.519670     7.847801
# min    2024.000000     83.910000     5.000000
# 25%    2024.000000   5716.353000    11.000000
# 50%    2024.000000  11471.660000    18.000000
# ...

# %%
df.describe(include="all")
# Out:
#         Order ID      Product Name     Category   Price (INR)  Quantity Sold  \
# count       1000              1000         1000   1000.000000    1000.000000
# unique      1000                25            5           NaN            NaN
# top     ORD01000  Educational Book  Electronics           NaN            NaN
# freq           1                64          217           NaN            NaN
# mean         NaN               NaN          NaN  24520.258260       3.097000
# std          NaN               NaN          NaN  14187.611227       1.410525
# min          NaN               NaN          NaN    139.850000       1.000000
# 25%          NaN               NaN          NaN  12378.905000       2.000000
# 50%          NaN               NaN          NaN  24650.015000       3.000000
# 75%          NaN               NaN          NaN  35981.925000       4.000000
# max          NaN               NaN          NaN  49911.750000       5.000000
#
# ...

# %%
df.isnull().sum()
# Out:
# Order ID             0
# Product Name         0
# Category             0
# Price (INR)          0
# Quantity Sold        0
# Total Sales (INR)    0
# Order Date           0
# Payment Method       0
# Customer Rating      0
# Month                0
# Year                 0
# Profit (INR)         0
# Discount %           0
# Customer Segment     0
# Region               0
# dtype: int64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df
# Out:
#      Order ID      Product Name        Category  Price (INR)  Quantity Sold  \
# 0    ORD00001  Educational Book           Books     49069.56              2
# 1    ORD00002             Jeans        Clothing     12755.85              4
# 2    ORD00003        Face Cream          Beauty     11092.19              4
# 3    ORD00004        Smartwatch     Electronics     32657.81              1
# 4    ORD00005      Cookware Set  Home & Kitchen     26590.08              3
# ..        ...               ...             ...          ...            ...
# 995  ORD00996        Smartphone     Electronics     28995.81              3
# 996  ORD00997           Perfume          Beauty     32799.51              2
# 997  ORD00998        Face Cream          Beauty     40840.80              1
# 998  ORD00999      Cookware Set  Home & Kitchen     34741.79              4
# 999  ORD01000        Table Lamp  Home & Kitchen     16698.12              4
#
# ...

# %%
df['Order Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Total Sales (INR)'].sum()
# Out:
# np.float64(75213112.74000001)

# %%
df['Profit (INR)'].sum()
# Out:
# np.float64(15042622.548)

# %%
df['Total Sales (INR)'].mean()
# Out:
# np.float64(75213.11274000001)

# %%
category_sales = df.groupby('Category')['Total Sales (INR)'].sum().sort_values(ascending=False)
print(category_sales)
# Out:
# Category
# Electronics       17307173.07
# Clothing          15114386.86
# Books             14785759.65
# Beauty            14680584.05
# Home & Kitchen    13325209.11
# Name: Total Sales (INR), dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
category_sales.plot(kind='bar')
plt.title("Revenue by Category")
plt.xlabel("Category")
plt.ylabel("Revenue")
plt.show()

# %%
df
# Out:
#      Order ID      Product Name        Category  Price (INR)  Quantity Sold  \
# 0    ORD00001  Educational Book           Books     49069.56              2
# 1    ORD00002             Jeans        Clothing     12755.85              4
# 2    ORD00003        Face Cream          Beauty     11092.19              4
# 3    ORD00004        Smartwatch     Electronics     32657.81              1
# 4    ORD00005      Cookware Set  Home & Kitchen     26590.08              3
# ..        ...               ...             ...          ...            ...
# 995  ORD00996        Smartphone     Electronics     28995.81              3
# 996  ORD00997           Perfume          Beauty     32799.51              2
# 997  ORD00998        Face Cream          Beauty     40840.80              1
# 998  ORD00999      Cookware Set  Home & Kitchen     34741.79              4
# 999  ORD01000        Table Lamp  Home & Kitchen     16698.12              4
#
# ...

# %%
ratings_by_segment=df.groupby("Customer Segment")["Customer Rating"].mean()

# %%
ratings_by_segment
# Out:
# Customer Segment
# Online       3.068580
# Retail       2.983481
# Wholesale    2.981818
# Name: Customer Rating, dtype: float64

# %%
monthly_sales=df.groupby('Month')['Total Sales (INR)'].sum()

# %%
monthly_sales
# Out:
# Month
# April        7334962.92
# August       5418893.98
# December     6491639.99
# February     5416573.21
# January      7160788.17
# July         7637324.95
# June         4992364.75
# March        6508879.04
# May          6706004.97
# November     5578535.08
# October      5702923.37
# September    6264222.31
# Name: Total Sales (INR), dtype: float64

# %%
monthly_sales.plot(kind='bar')
plt.title("SALES BY MONTH")
# Out:
# Text(0.5, 1.0, 'SALES BY MONTH')

# %%
df['day']=df['Order Date'].dt.day_name()

# %%
df['day']
# Out:
# 0       Thursday
# 1      Wednesday
# 2       Saturday
# 3         Friday
# 4         Friday
#          ...
# 995       Monday
# 996    Wednesday
# 997       Friday
# 998    Wednesday
# 999      Tuesday
# Name: day, Length: 1000, dtype: object

# %%
df
# Out:
#      Order ID      Product Name        Category  Price (INR)  Quantity Sold  \
# 0    ORD00001  Educational Book           Books     49069.56              2
# 1    ORD00002             Jeans        Clothing     12755.85              4
# 2    ORD00003        Face Cream          Beauty     11092.19              4
# 3    ORD00004        Smartwatch     Electronics     32657.81              1
# 4    ORD00005      Cookware Set  Home & Kitchen     26590.08              3
# ..        ...               ...             ...          ...            ...
# 995  ORD00996        Smartphone     Electronics     28995.81              3
# 996  ORD00997           Perfume          Beauty     32799.51              2
# 997  ORD00998        Face Cream          Beauty     40840.80              1
# 998  ORD00999      Cookware Set  Home & Kitchen     34741.79              4
# 999  ORD01000        Table Lamp  Home & Kitchen     16698.12              4
#
# ...

# %%
df.columns=df.columns.str.upper()

# %%
df
# Out:
#      ORDER ID      PRODUCT NAME        CATEGORY  PRICE (INR)  QUANTITY SOLD  \
# 0    ORD00001  Educational Book           Books     49069.56              2
# 1    ORD00002             Jeans        Clothing     12755.85              4
# 2    ORD00003        Face Cream          Beauty     11092.19              4
# 3    ORD00004        Smartwatch     Electronics     32657.81              1
# 4    ORD00005      Cookware Set  Home & Kitchen     26590.08              3
# ..        ...               ...             ...          ...            ...
# 995  ORD00996        Smartphone     Electronics     28995.81              3
# 996  ORD00997           Perfume          Beauty     32799.51              2
# 997  ORD00998        Face Cream          Beauty     40840.80              1
# 998  ORD00999      Cookware Set  Home & Kitchen     34741.79              4
# 999  ORD01000        Table Lamp  Home & Kitchen     16698.12              4
#
# ...

# %%
df=df.drop('DAY',axis=1)

# %%
df
# Out:
#      ORDER ID      PRODUCT NAME        CATEGORY  PRICE (INR)  QUANTITY SOLD  \
# 0    ORD00001  Educational Book           Books     49069.56              2
# 1    ORD00002             Jeans        Clothing     12755.85              4
# 2    ORD00003        Face Cream          Beauty     11092.19              4
# 3    ORD00004        Smartwatch     Electronics     32657.81              1
# 4    ORD00005      Cookware Set  Home & Kitchen     26590.08              3
# ..        ...               ...             ...          ...            ...
# 995  ORD00996        Smartphone     Electronics     28995.81              3
# 996  ORD00997           Perfume          Beauty     32799.51              2
# 997  ORD00998        Face Cream          Beauty     40840.80              1
# 998  ORD00999      Cookware Set  Home & Kitchen     34741.79              4
# 999  ORD01000        Table Lamp  Home & Kitchen     16698.12              4
#
# ...

# %%
df['DAY']=df['ORDER DATE'].dt.day_name()

# %%
df
# Out:
#      ORDER ID      PRODUCT NAME        CATEGORY  PRICE (INR)  QUANTITY SOLD  \
# 0    ORD00001  Educational Book           Books     49069.56              2
# 1    ORD00002             Jeans        Clothing     12755.85              4
# 2    ORD00003        Face Cream          Beauty     11092.19              4
# 3    ORD00004        Smartwatch     Electronics     32657.81              1
# 4    ORD00005      Cookware Set  Home & Kitchen     26590.08              3
# ..        ...               ...             ...          ...            ...
# 995  ORD00996        Smartphone     Electronics     28995.81              3
# 996  ORD00997           Perfume          Beauty     32799.51              2
# 997  ORD00998        Face Cream          Beauty     40840.80              1
# 998  ORD00999      Cookware Set  Home & Kitchen     34741.79              4
# 999  ORD01000        Table Lamp  Home & Kitchen     16698.12              4
#
# ...

# %%
df.to_csv("flipkart_cleaned.csv", index=False)

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Somya Kala\flipkart

# %%
df.to_csv(r"C:\Users\Somya Kala\Downloads\flipkart_cleaned.csv", index=False)
